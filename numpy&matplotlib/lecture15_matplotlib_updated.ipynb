# %% [markdown]
# # Lecture 15:  Matplotlib and pyplot
#
# __Reading Material:__
# - [Matplotlib tutorial](https://matplotlib.org/users/pyplot_tutorial.html)

# %% [markdown]
# ## Matplotlib and pyplot

# %% [markdown]
# We will be working a lot with __matplotlib__ and __pyplot__, and its most basic function: plot(), which takes as input a list of x-coordinates and y-coordinates, and plots those points. In its most basic form, it plots them and connectes them by a line.
#
# You may need to insert, at the beginning of the notebook the following magic:
#
# %matplotlib inline

# %%
# %matplotlib inline #not gonna work in spyder
import matplotlib.pyplot as plt
plt.plot([0,1,2,3],[5,9,3,2])
plt.show()

# %%
# plt.plot([0,1,2,3],[5,9,3,2],'ro') #red points
# plt.plot([0,1,2,3],[5,9,3,2],'ks') #black squares
# plt.plot([0,1,2,3],[5,9,3,2],'k-') #black solid line
# plt.plot([0,1,2,3],[5,9,3,2],'k-.') #black dashed line
plt.plot([0,1,2,3],[5,9,3,2],'bo-') #blue solid points connected by solid line

# %%
x = [0,1,2,3]
y1 = [5,9,3,2]
y2 = [3,4,2,6]
plt.plot(x, y1,'bo-', x, y2, 'r-.')
# Out:
# [<matplotlib.lines.Line2D at 0x11d616410>,
#  <matplotlib.lines.Line2D at 0x11d6165d0>]

# %% [markdown]
# We can also specify the linestyle. For example, we can ask for discrete points (o for bullets), and specify a color (r for red):

# %%
plt.plot([0,1,2,3],[5,9,3,2],'ro')
plt.show()

# %% [markdown]
# To make our plot more readable, we can change the axes range, and add a title and axis labels. We can also plot multiple plots in the same figure, by adding them to the same execution. For example:

# %%
plt.plot([0,1,2,3],[5,9,3,2],'ro',[0,1,2,3],[3,4,5,6],'ko-')
plt.axis([-1,4,0,10])
plt.title('My plot')
plt.xlabel('horizontal')
plt.ylabel('vertical')
plt.show()

# %% [markdown]
# ### Example:
# - Use __plt.plot( )__ to draw a sin(x) function. Do this by plotting many points, which together look like a smooth line.

# %%
import math
N = 100
dx = 2*math.pi/(N-1)
x_list = [i*dx for i in range(N)]
y_list = [math.sin(xi) for xi in x_list]
plt.plot(x_list, y_list)
plt.show()

# %% [markdown]
# Here is a much easier way to generate the same plot using __NumPy__:

# %%
import numpy as np

# %%
x = np.linspace(0,1,10)
print(x)
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]

# %%
x = np.linspace(0,np.pi,10)
print(x)
# Out:
# [0.         0.34906585 0.6981317  1.04719755 1.3962634  1.74532925
#  2.0943951  2.44346095 2.7925268  3.14159265]

# %%
[1, "abc",{1:2}]
# Out:
# [1, 'abc', {1: 2}]

# %%
print(type(x))
print(x.dtype)
# Out:
# <class 'numpy.ndarray'>
# float64

# %%
x_list = [1,2,3]
print(2*x_list)
print(x_list+2)
# Out:
# [1, 2, 3, 1, 2, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-d0f505df10a9> in <module>
#       1 x_list = [1,2,3]
#       2 print(2*x_list)
# ----> 3 print(x_list+2)
#
# TypeError: can only concatenate list (not "int") to list

# %%
y = 2*x
print(y)
# Out:
# [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]

# %%
x/2
# Out:
# array([0.        , 0.17453293, 0.34906585, 0.52359878, 0.6981317 ,
#        0.87266463, 1.04719755, 1.22173048, 1.3962634 , 1.57079633])

# %%
y = np.sin(x)
print(y)
# Out:
# [0.00000000e+00 3.42020143e-01 6.42787610e-01 8.66025404e-01
#  9.84807753e-01 9.84807753e-01 8.66025404e-01 6.42787610e-01
#  3.42020143e-01 1.22464680e-16]

# %%
N = 1000
x = np.linspace(0,2*np.pi,N)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
# list(range(0,5,2))
# range(0,5,0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b18f795ec7fe> in <module>
#       1 # list(range(0,5,2))
# ----> 2 range(0,5,0.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.arange(0., 5., 0.2)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
# evenly sampled x-coordinates at 0.2 intervals
x = np.arange(0., 5., 0.2) # x is now a numpy array

# red dashes, blue squares and green triangles
plt.plot(x,np.sin(x),'ro-')
plt.plot(x, x, 'ro', x, x**2, 'bs', x, x**3, 'g^')
plt.show()

# %%
np.arange(0., 5., 0.2)

# %%
x = np.linspace(0, 2, 5, endpoint = True)
print(x)
print(2*x)
# Out:
# [0.  0.5 1.  1.5 2. ]
# [0. 1. 2. 3. 4.]

# %%
x = np.linspace(0, 2, 5, endpoint = False)
print(x)
plt.plot(x, 2*x, 'rp')
plt.show()
# Out:
# [0.  0.4 0.8 1.2 1.6]

# %% [markdown]
# ### Exercises:

# %% [markdown]
# - Use __plt.plot( )__ to write a function that draws regular n-gons.

# %% [markdown]
# - Use __plt.plot( )__ to plot the error in Newton's method for approximating roots in each iteration
